# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 58.4MB/s]

# %%
model.train()
# Out:
# Ultralytics YOLOv8.0.197 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# model.val()

# %%
model.predict(save=True)
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 186.2ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 1 tennis racket, 155.9ms
# Speed: 3.3ms preprocess, 171.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
