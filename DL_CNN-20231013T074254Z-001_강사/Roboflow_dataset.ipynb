# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="vOJCnFpStyQAaxJVYCrE")
project = rf.workspace("joaoissamu").project("objectdetect-fs9hx")
dataset = project.version(1).download("yolov8")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO(model='yolov8s.pt', task='detect')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 243MB/s]

# %%
model.train(data='/content/ObjectDetect-1/data.yaml',
            epochs=1,
            patience=1,
            save=True,
            pretrained=True,
            verbose=False,
            seed=2023
            )

# %%
results = model.predict(source='/content/face_2.mp4',
                       save=True, line_width=2,
                       stream=True)

# %%
for r in results:
    boxes = r.boxes
# Out:
# Results saved to runs/detect/predict5
